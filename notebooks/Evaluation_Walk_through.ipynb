# %% [markdown]
# ## Update all data

# %%
# %load ../src/data/get_data_test.py

import subprocess
import os

import pandas as pd
import numpy as np

from datetime import datetime

import requests
import json

def get_johns_hopkins():
    ''' Get data by a git pull request, the source code has to be pulled first
        Result is stored in the predifined csv structure
    '''
    git_pull = subprocess.Popen( "git pull" ,
                         cwd = os.path.dirname('../data/raw/COVID-19/'),
                         shell = True,
                         stdout = subprocess.PIPE,
                         stderr = subprocess.PIPE )
    (out, error) = git_pull.communicate()


    print("Error : " + str(error))
    print("out : " + str(out))


def get_current_data_germany():
    ''' Get current data from germany, attention API endpoint not too stable
        Result data frame is stored as pd.DataFrame

    '''
    # 16 states
    #data=requests.get('https://services7.arcgis.com/mOBPykOjAyBO2ZKk/arcgis/rest/services/Coronaf%C3%A4lle_in_den_Bundesl%C3%A4ndern/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

    # 400 regions / Landkreise
    data=requests.get('https://services7.arcgis.com/mOBPykOjAyBO2ZKk/arcgis/rest/services/RKI_Landkreisdaten/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

    json_object=json.loads(data.content)
    full_list=[]
    for pos,each_dict in enumerate (json_object['features'][:]):
        full_list.append(each_dict['attributes'])

    pd_full_list=pd.DataFrame(full_list)
    pd_full_list.to_csv('../data/raw/NPGEO/GER_state_data.csv',sep=';')
    print(' Number of regions rows: '+str(pd_full_list.shape[0]))

if __name__ == '__main__':
    get_johns_hopkins()
    #get_current_data_germany()
# Out:
# Error : b'From https://github.com/CSSEGISandData/COVID-19\n   979bcb7816..e24bb46680  master        -> origin/master\n * [new branch]            Nicaragua_Fix -> origin/Nicaragua_Fix\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-06-21-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-06-21-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-06-23-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-06-23-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-06-24-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-06-24-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-08-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-08-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-10-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-10-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-11-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-11-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-12-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-12-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-13-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-13-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-14-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-14-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-15-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-15-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-16-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-16-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-17-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-17-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-18-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-18-2022\n * [new branch]            automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-19-2022 -> origin/automated-patch-for-delayed-data-for-India-Pakistan-Mexico-Peru-06-19-2022\n * [new branch]            automated-patch-for-delayed-data-for-Peru-06-21-2022 -> origin/automated-patch-for-delayed-data-for-Peru-06-21-2022\n * [new branch]            automated-patch-for-delayed-data-for-Peru-06-22-2022 -> origin/automated-patch-for-delayed-data-for-Peru-06-22-2022\n * [new branch]            automated-patch-for-delayed-data-for-Peru-06-23-2022 -> origin/automated-patch-for-delayed-data-for-Peru-06-23-2022\n * [new branch]            automated-patch-for-delayed-data-for-Peru-06-24-2022 -> origin/automated-patch-for-delayed-data-for-Peru-06-24-2022\n   60a8780100..a4e6c39399  web-data      -> origin/web-data\n * [new branch]            weekly-nd     -> origin/weekly-nd\nUpdating files:  10% (178/1634)\rUpdating files:  11% (180/1634)\rUpdating files:  12% (197/1634)\rUpdating files:  13% (213/1634)\rUpdating files:  14% (229/1634)\rUpdating files:  15% (246/1634)\rUpdating files:  16% (262/1634)\rUpdating files:  17% (278/1634)\rUpdating files:  18% (295/1634)\rUpdating files:  19% (311/1634)\rUpdating files:  20% (327/1634)\rUpdating files:  20% (332/1634)\rUpdating files:  21% (344/1634)\rUpdating files:  22% (360/1634)\rUpdating files:  23% (376/1634)\rUpdating files:  24% ...
_covid_19_daily_reports/01-17-2022.csv     |  282 +-\n .../csse_covid_19_daily_reports/01-18-2021.csv     |  234 +-\n .../csse_covid_19_daily_reports/01-18-2022.csv     |  286 +-\n .../csse_covid_19_daily_reports/01-19-2021.csv     |  232 +-\n .../csse_covid_19_daily_reports/01-19-2022.csv     |  286 +-\n .../csse_covid_19_daily_reports/01-20-2021.csv     |  232 +-\n .../csse_covid_19_daily_reports/01-20-2022.csv     |  290 +-\n .../csse_covid_19_daily_reports/01-21-2021.csv     |  230 +-\n .../csse_covid_19_daily_reports/01-21-2022.csv     |  292 +-\n .../csse_covid_19_daily_reports/01-22-2021.csv     |  228 +-\n .../csse_covid_19_daily_reports/01-22-2022.csv     |  292 +-\n .../csse_covid_19_daily_reports/01-23-2021.csv     |  228 +-\n .../csse_covid_19_daily_reports/01-23-2022.csv     |  294 +-\n .../csse_covid_19_daily_reports/01-24-2021.csv     |  232 +-\n .../csse_covid_19_daily_reports/01-24-2022.csv     |  300 +-\n .../csse_covid_19_daily_reports/01-25-2021.csv     |  232 +-\n .../csse_covid_19_daily_reports/01-25-2022.csv     |  304 +-\n .../csse_covid_19_daily_reports/01-26-2021.csv     |  226 +-\n .../csse_covid_19_daily_reports/01-26-2022.csv     |  300 +-\n .../csse_covid_19_daily_reports/01-27-2021.csv     |  230 +-\n .../csse_covid_19_daily_reports/01-27-2022.csv     |  304 +-\n .../csse_covid_19_daily_reports/01-28-2021.csv     |  230 +-\n .../csse_covid_19_daily_reports/01-28-2022.csv     |  304 +-\n .../csse_covid_19_daily_reports/01-29-2021.csv     |  228 +-\n .../csse_covid_19_daily_reports/01-29-2022.csv     |  304 +-\n .../csse_covid_19_daily_reports/01-30-2021.csv     |  226 +-\n .../csse_covid_19_daily_reports/01-30-2022.csv     |  304 +-\n .../csse_covid_19_daily_reports/01-31-2 ...
#  Number of regions rows: 411

# %% [markdown]
# ## Process pipeline

# %%
# %load ../src/data/process_JH_data_test.py
import pandas as pd
import numpy as np

from datetime import datetime


def store_relational_JH_data():
    ''' Transformes the COVID data in a relational data set

    '''

    data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
    pd_raw=pd.read_csv(data_path)

    pd_data_base=pd_raw.rename(columns={'Country/Region':'country',
                      'Province/State':'state'})

    pd_data_base['state']=pd_data_base['state'].fillna('no')

    pd_data_base=pd_data_base.drop(['Lat','Long'],axis=1)


    pd_relational_model=pd_data_base.set_index(['state','country']) \
                                .T                              \
                                .stack(level=[0,1])             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )

    pd_relational_model['date']=pd_relational_model.date.astype('datetime64[ns]')

    pd_relational_model.to_csv('../data/processed/COVID_relational_confirmed.csv',sep=';',index=False)
    print(' Number of rows stored: '+str(pd_relational_model.shape[0]))

if __name__ == '__main__':

    store_relational_JH_data()
# Out:
#  Number of rows stored: 247380
